# %%
import pandas as pd

data = {
"Name": [
    "Alice", "Bob", "Charlie", "David", "Evelyn",
    "Frank", "Grace", "Henry", "Isla", "Jack",
    "Karen", "Leo", "Mia", "Noah", "Olivia",
    "Paul", "Quinn", "Ruby", "Sam", "Tina"
],
"Age": [25, 32, 37, 29, 41, 28, 34, 45, 26, 31, 39, 27, 33, 36, 30, 42, 24, 38, 35, 29],
"Department": [
    "HR", "Engineering", "Sales", "Marketing", "Engineering",
    "Finance", "Support", "Operations", "HR", "Sales",
    "Engineering", "Support", "Marketing", "Finance", "Operations",
    "Engineering", "HR", "Sales", "Support", "Marketing"
],
"Salary": [
    50000, 75000, 62000, 58000, 80000,
    54000, 52000, 70000, 51000, 64000,
    82000, 53000, 60000, 56000, 68000,
    79000, 49500, 65500, 54500, 61000
],
}

df = pd.DataFrame(data)

# %% [markdown]
# ### 1.Printing first five rows of DataFrame

# %%
df.head()
# Out:
#       Name  Age   Department  Salary
# 0    Alice   25           HR   50000
# 1      Bob   32  Engineering   75000
# 2  Charlie   37        Sales   62000
# 3    David   29    Marketing   58000
# 4   Evelyn   41  Engineering   80000

# %% [markdown]
# ### 2.Printing last five rows of DataFrame

# %%
print(df.tail())
# Out:
#      Name  Age   Department  Salary
# 15   Paul   42  Engineering   79000
# 16  Quinn   24           HR   49500
# 17   Ruby   38        Sales   65500
# 18    Sam   35      Support   54500
# 19   Tina   29    Marketing   61000

# %% [markdown]
# ### 3.Basic info about dataframe

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        20 non-null     str
#  1   Age         20 non-null     int64
#  2   Department  20 non-null     str
#  3   Salary      20 non-null     int64
# dtypes: int64(2), str(2)
# memory usage: 772.0 bytes

# %% [markdown]
# ### 4.Check the shape of data

# %%
df.shape
# Out:
# (20, 4)

# %%
type(df)
# Out:
# pandas.DataFrame

# %%
df.Age
# Out:
# 0     25
# 1     32
# 2     37
# 3     29
# 4     41
# 5     28
# 6     34
# 7     45
# 8     26
# 9     31
# 10    39
# 11    27
# 12    33
# 13    36
# 14    30
# 15    42
# 16    24
# 17    38
# 18    35
# 19    29
# Name: Age, dtype: int64

# %%
df['Age'].head()
# Out:
# 0    25
# 1    32
# 2    37
# 3    29
# 4    41
# Name: Age, dtype: int64

# %%
df[['Name', 'Salary', 'Department']].head()
# Out:
#       Name  Salary   Department
# 0    Alice   50000           HR
# 1      Bob   75000  Engineering
# 2  Charlie   62000        Sales
# 3    David   58000    Marketing
# 4   Evelyn   80000  Engineering

# %%
df[df['Age'] < 30]
# Out:
#      Name  Age Department  Salary
# 0   Alice   25         HR   50000
# 3   David   29  Marketing   58000
# 5   Frank   28    Finance   54000
# 8    Isla   26         HR   51000
# 11    Leo   27    Support   53000
# 16  Quinn   24         HR   49500
# 19   Tina   29  Marketing   61000

# %%
df[(df['Age'] < 30) & (df['Department'] == 'HR')]
# Out:
#      Name  Age Department  Salary
# 0   Alice   25         HR   50000
# 8    Isla   26         HR   51000
# 16  Quinn   24         HR   49500

# %%
df.loc[0]
# Out:
# Name          Alice
# Age              25
# Department       HR
# Salary        50000
# Name: 0, dtype: object

# %%
df.loc[0:2]
# Out:
#       Name  Age   Department  Salary
# 0    Alice   25           HR   50000
# 1      Bob   32  Engineering   75000
# 2  Charlie   37        Sales   62000

# %%
df.loc[0:2, ['Name', 'Age']]
# Out:
#       Name  Age
# 0    Alice   25
# 1      Bob   32
# 2  Charlie   37

# %%
df.iloc[0]
# Out:
# Name          Alice
# Age              25
# Department       HR
# Salary        50000
# Name: 0, dtype: object

# %%
df.iloc[0:3]
# Out:
#       Name  Age   Department  Salary
# 0    Alice   25           HR   50000
# 1      Bob   32  Engineering   75000
# 2  Charlie   37        Sales   62000

# %%
df.iloc[0:3, 0:2]
# Out:
#       Name  Age
# 0    Alice   25
# 1      Bob   32
# 2  Charlie   37
